# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Importing Libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import scipy.stats as stats
from scipy.stats import norm 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the dataset

# %%
df=pd.read_csv('BASEBALL CASE STUDY.CSV')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The dataset contains 30 rows and 17 columns

# %% [markdown]
# Datatype of the features

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# Column Names

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Information about the features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# unique values of CG

# %%
print(df['CG'].value_counts())
# Out:
# 1     7
# 7     4
# 2     4
# 6     3
# 5     3
# 3     3
# 0     3
# 4     2
# 11    1
# Name: CG, dtype: int64

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Heatmap of the null values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Statistical Calculation

# %%
df.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %% [markdown]
# Mean is less than 75th percentile in all the columns.
#   There are no extreme outliers present.
#  Except CG no other column contain min value as zero.

# %% [markdown]
# Statistical heatmap

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidths=0.1,linecolor='white')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# Heatmap of correlation

# %%
plt.figure(figsize=(20,16))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1.ERA is strongly positively correlated with RA.

# %% [markdown]
# 2.ER is also strongly positively correlated with RA.

# %% [markdown]
# 3.ER is completely positively correlated with ERA.

# %%
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color="c")
plt.xlabel('Features',fontsize=14)
plt.ylabel('column with target name',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# 1.The above plot shows correlation of features with the target variable "W".
#
# 2.ER,RA,ERA are strongly negatively correlated with "W"

# %% [markdown]
# ### For the purpose visualisation the dataset is divided in three parts:"offense","pitching","defense".

# %%
offense=df[['R','AB','H','2B','3B','HR','BB','SB','W']]
pitching=df[['SO','RA','ER','ERA','SHO','SV','CG','W']]
defense=df[['E','W']]

# %%
df1=offense
df1.head()
# Out:
#      R    AB     H   2B  3B   HR   BB   SB   W
# 0  724  5575  1497  300  42  139  383  104  95
# 1  696  5467  1349  277  44  156  439   70  83
# 2  669  5439  1395  303  29  141  533   86  81
# 3  622  5533  1381  260  27  136  404   68  76
# 4  689  5605  1515  289  49  151  455   83  74

# %%
df1= pd.melt(df1, id_vars="W", var_name="offense", value_name="Values")
df1.head()
# Out:
#     W offense  Values
# 0  95       R     724
# 1  83       R     696
# 2  81       R     669
# 3  76       R     622
# 4  74       R     689

# %%
plt.figure(figsize=(10,8))
plt.title("Representation of offense features")
sns.barplot(x='offense',y="Values",data=df1);

# %% [markdown]
# Above plot shows the representation of offense features wherein AB has values above 5000.

# %%
plt.figure(figsize=(10,8))
df2=pitching
df2= pd.melt(df2, id_vars="W", var_name="pitching", value_name="Values")
plt.title("Representation of pitching features")
sns.barplot(x='pitching',y="Values",data=df2);

# %% [markdown]
# Above plot shows the representation of pitching features wherein SO has values above 1200.

# %%
df3=defense
df3= pd.melt(df3, id_vars="W", var_name="defense", value_name="Values")
plt.title("Representation of defense feature")
sns.barplot(x='defense',y="Values",data=df3);

# %% [markdown]
# Defense feature's value are above 80.

# %%
sns.barplot(x='CG',y="W",data=df);

# %% [markdown]
# Above Bar plot shows relation between CG and W. At 6 complete Games, wins were highest.

# %% [markdown]
# # Distribution and Probability plot.

# %%
sns.distplot(offense['R'],fit=norm);
fig=plt.figure()
res=stats.probplot(offense['R'],plot=plt)

# %% [markdown]
# Above plot shows values are almost normally distributed.

# %%
sns.distplot(offense['AB'],fit=norm);
fig=plt.figure()
res=stats.probplot(offense['AB'],plot=plt)

# %% [markdown]
# Above plot shows almost normal distribution.

# %%
sns.distplot(offense['H'],fit=norm);
fig=plt.figure()
res=stats.probplot(offense['H'],plot=plt)

# %% [markdown]
# Above plot shows bimodal distribution and shows  slight positive skewness.

# %%
sns.distplot(offense['2B'],fit=norm);
fig=plt.figure()
res=stats.probplot(offense['2B'],plot=plt)

# %% [markdown]
# Above plot is almost normally distributed.

# %%
sns.distplot(offense['3B'],fit=norm);
fig=plt.figure()
res=stats.probplot(offense['3B'],plot=plt)

# %% [markdown]
# Above plot is normally distributed.

# %%
sns.distplot(offense['HR'],fit=norm);
fig=plt.figure()
res=stats.probplot(offense['HR'],plot=plt)

# %% [markdown]
# Above plot shows values are almost normally distributed with slight positive skewness.

# %%
sns.distplot(offense['BB'],fit=norm);
fig=plt.figure()
res=stats.probplot(offense['BB'],plot=plt)

# %% [markdown]
# Above plot shows values are almost normally distributed with slight positive skewness.

# %%
sns.distplot(offense['SB'],fit=norm);
fig=plt.figure()
res=stats.probplot(offense['SB'],plot=plt)

# %% [markdown]
# Above plot shows values are almost normally distributed with slight positive skewness.

# %%
df2
# Out:
#       W pitching  Values
# 0    95       SO   973.0
# 1    83       SO  1264.0
# 2    81       SO  1157.0
# 3    76       SO  1231.0
# 4    74       SO  1259.0
# ..   ..      ...     ...
# 205  92       CG     6.0
# 206  84       CG     7.0
# 207  79       CG     1.0
# 208  74       CG     1.0
# 209  68       CG     4.0
#
# [210 rows x 3 columns]

# %%
sns.distplot(pitching['SO'],fit=norm);
fig=plt.figure()
res=stats.probplot(pitching['SO'],plot=plt)

# %% [markdown]
# Above plot is almost normally distributed with slight negative skewness.

# %%
sns.distplot(pitching['RA'],fit=norm);
fig=plt.figure()
res=stats.probplot(pitching['RA'],plot=plt)

# %% [markdown]
# Above plot is almost normally distributed.

# %%
sns.distplot(pitching['ER'],fit=norm);
fig=plt.figure()
res=stats.probplot(pitching['ER'],plot=plt)

# %% [markdown]
# Above plot is almost normally distributed.

# %%
sns.distplot(pitching['ERA'],fit=norm);
fig=plt.figure()
res=stats.probplot(pitching['ERA'],plot=plt)

# %% [markdown]
# Above plot shows that values are normally distributed.

# %%
sns.distplot(pitching['SHO'],fit=norm);
fig=plt.figure()
res=stats.probplot(pitching['SHO'],plot=plt)

# %% [markdown]
# Above plot shows some discrete values .

# %%
sns.distplot(pitching['SV'],fit=norm);
fig=plt.figure()
res=stats.probplot(pitching['SV'],plot=plt)

# %% [markdown]
# Above plot shows is positively skewed.

# %%
sns.distplot(pitching['CG'],fit=norm);
fig=plt.figure()
res=stats.probplot(pitching['CG'],plot=plt)

# %% [markdown]
# Above plot shows values are discrete.

# %%
sns.distplot(defense['E'],fit=norm);
fig=plt.figure()
res=stats.probplot(defense['E'],plot=plt)

# %% [markdown]
# Above plot is positively skewed.

# %%
sns.distplot(df['W'],fit=norm);
fig=plt.figure()
res=stats.probplot(df['W'],plot=plt)

# %% [markdown]
# Above plot is almost normally distributed.

# %%
sns.set_style('whitegrid')
sns.lineplot(x='RA',y="ERA",data=df,color="red");

# %% [markdown]
# Above plot shows that as values of RA subsequently ERA also increases

# %%
sns.set_style('whitegrid')
sns.lineplot(x='R',y="W",data=df,color="red");

# %% [markdown]
# Above plot shows that as the R increases beyond 760 it shows wins are increasing linearly.

# %%
sns.set_style('whitegrid')
sns.lineplot(x='RA',y="ER",data=df,color="red");

# %% [markdown]
# Above plot shows both RA and ER are almost linearly related to each other.

# %%
sns.lineplot(x='HR',y="W",data=offense,color="red");

# %% [markdown]
# Above plot shows that at 130 HR the wins are hightest and overall shows positive linear relationship between both.

# %%
sns.set_style('whitegrid')
sns.lineplot(x='ER',y="ERA",data=df,color="red");

# %% [markdown]
# Above plot shows that ER and ERA have linear relationship.

# %%
sns.set_style('whitegrid')
sns.lineplot(x='RA',y="W",data=df,color="red");

# %% [markdown]
# Above plot shows that RA and W are inversely proportional to each other and highest wins at 540 RA.

# %%
sns.set_style('whitegrid')
sns.lineplot(x='ERA',y="W",data=df,color="red");

# %% [markdown]
# Above plot shows that ERA and W are inversely propotional to each other and highest wins are at 2.5 ERA.

# %%
sns.set_style('whitegrid')
sns.lineplot(x='ER',y="W",data=df,color='red');

# %% [markdown]
# Above plot shows that ER and W are inversely propotional to each other and highest wins are at 450 ER.

# %%
sns.set_style('whitegrid')
sns.lineplot(x='CG',y="W",data=df,color="red");

# %% [markdown]
# Above plot shows that after nearly 7 CG wins remain constant.

# %% [markdown]
# # Box Plots showing outliers

# %%
collist=offense.columns.values
ncol=3
nrows=3
plt.figure(figsize=(12,4*ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(offense[collist[i]],color='yellow',orient='v')
    plt.tight_layout()

# %% [markdown]
# R shows 1 outlier all other features do not have outliers.

# %%
collist=pitching.columns.values
ncol=3
nrows=3
plt.figure(figsize=(12,4*ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(pitching[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# ERA,SHO and SV shows presence of outliers.

# %%
collist=defense.columns.values
ncol=3
nrows=3
plt.figure(figsize=(12,4*ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(defense[collist[i]],color='red',orient='v')
    plt.tight_layout()

# %% [markdown]
# E shows presence of outliers.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(offense,size=3,palette="bright")

# %%
sns.pairplot?

# %%
sns.pairplot(pitching,size=3,palette="bright")

# %% [markdown]
# ERA is directly related with RA. Also ER is directly propotional to RA. ER is directly proportional with ERA.

# %%
sns.pairplot(defense,size=3)

# %% [markdown]
# # Outlier Removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z[5][1]
# Out:
# 3.5096470447193067

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (29, 17)

# %%
(1/30)*100
# Out:
# 3.3333333333333335

# %%
df_new=df_new.drop(['RA', 'ER'], axis=1)

# %%
df_new.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0  95  724  5575  1497  300  42  139  383   973  104  3.73   2    8  56   88
# 1  83  696  5467  1349  277  44  156  439  1264   70  4.07   2   12  45   86
# 2  81  669  5439  1395  303  29  141  533  1157   86  3.67  11   10  38   79
# 3  76  622  5533  1381  260  27  136  404  1231   68  3.98   7    9  37  101
# 4  74  689  5605  1515  289  49  151  455  1259   83  4.64   7   12  35   86

# %% [markdown]
# # Separating x(Independent) and y(target) variable.

# %%
x = df_new.drop('W', axis=1)
y = df_new['W']

# %%
x.head(2)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV   E
# 0  724  5575  1497  300  42  139  383   973  104  3.73   2    8  56  88
# 1  696  5467  1349  277  44  156  439  1264   70  4.07   2   12  45  86

# %%
y.head(2)
# Out:
# 0    95
# 1    83
# Name: W, dtype: int64

# %% [markdown]
# # Removing Skewness

# %%
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
for index in x.skew().index:
    if x.skew().loc[index]>0.5:
        x[index]=np.log1p(x[index])
    if x.skew().loc[index]<-0.5:
        x[index]=np.square(x[index])

# %%
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# ERA    0.016693
# CG    -0.275681
# SHO   -0.116970
# SV     0.109983
# E      0.586101
# dtype: float64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
x.head(2)
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
#
#          SO        SB       ERA        CG       SHO        SV         E
# 0 -2.727623  0.905953 -0.511388 -0.240415 -0.784917  1.554812 -0.435733
# 1  0.121896 -0.585315  0.238952 -0.240415  0.255799  0.296229 -0.598110

# %% [markdown]
# # Finding the best random state

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
lr=LinearRegression()
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state{i},the training accuracy is:{r2_score(y_train,pred_train)}")
    print(f"At random state{i},the testing accuracy is:{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state0,the training accuracy is:0.9807221123040415
# At random state0,the testing accuracy is:0.2046142281550959
#
#
# At random state1,the training accuracy is:0.9863875923699433
# At random state1,the testing accuracy is:0.39130853977125146
#
#
# At random state2,the training accuracy is:0.9565508886885703
# At random state2,the testing accuracy is:-0.06239920776947594
#
#
# At random state3,the training accuracy is:0.9688594182257722
# At random state3,the testing accuracy is:0.45712716709995926
#
#
# At random state4,the training accuracy is:0.9656396387607558
# At random state4,the testing accuracy is:0.7880798907139382
#
#
# At random state5,the training accuracy is:0.9660969376675408
# At random state5,the testing accuracy is:0.4805780751561033
#
#
# At random state6,the training accuracy is:0.9591119176337211
# At random state6,the testing accuracy is:0.7296484703659338
#
#
# At random state7,the training accuracy is:0.9428926592999733
# ...

# %% [markdown]
# # Train Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# # Model Selection

# %% [markdown]
# # Linear Regression

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# 80.2332741482766

# %%
lm.score(x_train,y_train)
# Out:
# 0.9399595430298631

# %%
pred=lm.predict(x_test)
print("Predicted Sales:",pred)
print("Actual Sales:",y_test)
# Out:
# Predicted Sales: [74.87108196 91.14575607 77.96870164 66.6071695  80.21482178 80.58077266
#  70.63481568 91.90298091 81.83885011]
# Actual Sales: 28    74
# 17    97
# 13    76
# 23    67
# 9     78
# 10    88
# 22    71
# 0     95
# 27    79
# Name: W, dtype: int64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
print("r2 Score:",r2_score(y_test,pred))
print("Error:")
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 Score: 0.8676122846771178
# Error:
# Mean Absolute Error: 2.780217852695669
# Mean Squared Error: 12.977264934119566
# Root Mean Squared Error: 3.6023971094424843

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
dtr.score(x_test,y_test)
# Out:
# 0.05239294710327447

# %%
preddtr=dtr.predict(x_test)
print("Predicted Sales:",preddtr)
print("Actual Sales:",y_test)
# Out:
# Predicted Sales: [80. 92. 64. 64. 68. 68. 76. 86. 83.]
# Actual Sales: 28    74
# 17    97
# 13    76
# 23    67
# 9     78
# 10    88
# 22    71
# 0     95
# 27    79
# Name: W, dtype: int64

# %%
print("r2 Score:",r2_score(y_test,preddtr))
print("Error:")
print("Mean Absolute Error:",mean_absolute_error(y_test,preddtr))
print("Mean Squared Error:",mean_squared_error(y_test,preddtr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,preddtr)))
# Out:
# r2 Score: 0.05239294710327447
# Error:
# Mean Absolute Error: 8.222222222222221
# Mean Squared Error: 92.88888888888889
# Root Mean Squared Error: 9.637888196533973

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
svr.score(x_train,y_train)
# Out:
# 0.229435824049386

# %%
predsvr=svr.predict(x_test)
print("Predicted Sales:",predsvr)
print("Actual Sales:",y_test)
# Out:
# Predicted Sales: [80.04002235 81.9402141  81.46317322 80.78063633 80.63485402 80.81756474
#  80.60635927 81.13668314 80.86140682]
# Actual Sales: 28    74
# 17    97
# 13    76
# 23    67
# 9     78
# 10    88
# 22    71
# 0     95
# 27    79
# Name: W, dtype: int64

# %%
print("r2 Score:",r2_score(y_test,predsvr))
print("Error:")
print("Mean Absolute Error:",mean_absolute_error(y_test,predsvr))
print("Mean Squared Error:",mean_squared_error(y_test,predsvr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predsvr)))
# Out:
# r2 Score: 0.05976118036533051
# Error:
# Mean Absolute Error: 8.387998892563639
# Mean Squared Error: 92.16662009752191
# Root Mean Squared Error: 9.600344790554239

# %% [markdown]
# # Ensemble Technique

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.score(x_train,y_train)
# Out:
# 0.9557684082453966

# %%
predrfr=rfr.predict(x_test)
print("Predicted Sales:",predrfr)
print("Actual Sales:",y_test)
# Out:
# Predicted Sales: [80.5  92.19 75.73 71.59 73.53 72.79 76.77 84.03 82.85]
# Actual Sales: 28    74
# 17    97
# 13    76
# 23    67
# 9     78
# 10    88
# 22    71
# 0     95
# 27    79
# Name: W, dtype: int64

# %%
print("r2 Score:",r2_score(y_test,predrfr))
print("Error:")
print("Mean Absolute Error:",mean_absolute_error(y_test,predrfr))
print("Mean Squared Error:",mean_squared_error(y_test,predrfr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predrfr)))
# Out:
# r2 Score: 0.4260987909319902
# Error:
# Mean Absolute Error: 6.271111111111109
# Mean Squared Error: 56.25648888888886
# Root Mean Squared Error: 7.500432580117553

# %% [markdown]
# # xgboost

# %%
from xgboost import XGBRegressor
model=XGBRegressor(n_estimators=1000,learning_rate=0.05)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([78.01167 , 89.7374  , 70.7582  , 64.30652 , 70.419044, 70.70715 ,
#        73.66123 , 83.028725, 84.24129 ], dtype=float32)

# %%
model.score(x_train,y_train)
# Out:
# 0.9999999964822629

# %%
predxgb=model.predict(x_test)
print("Predicted Sales:",predxgb)
print("Actual Sales:",y_test)
# Out:
# Predicted Sales: [78.01167  89.7374   70.7582   64.30652  70.419044 70.70715  73.66123
#  83.028725 84.24129 ]
# Actual Sales: 28    74
# 17    97
# 13    76
# 23    67
# 9     78
# 10    88
# 22    71
# 0     95
# 27    79
# Name: W, dtype: int64

# %%
print("r2 Score:",r2_score(y_test,predxgb))
print("Error:")
print("Mean Absolute Error:",mean_absolute_error(y_test,predxgb))
print("Mean Squared Error:",mean_squared_error(y_test,predxgb))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predxgb)))
# Out:
# r2 Score: 0.2768847537826645
# Error:
# Mean Absolute Error: 7.106350368923611
# Mean Squared Error: 70.88314882673633
# Root Mean Squared Error: 8.419213076454136

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k=5
kfold=KFold(n_splits=k,shuffle=True)
K_results=cross_val_score(lm,x,y,cv=kfold)
accuracy=np.mean(abs(K_results))
accuracy
# Out:
# 0.6646074316408008

# %%
from sklearn.model_selection import KFold
k=5
kfold=KFold(n_splits=k,shuffle=True)
K_results=cross_val_score(dtr,x,y,cv=kfold)
accuracy=np.mean(abs(K_results))
accuracy
# Out:
# 0.5202586227106716

# %%
k=5
kfold=KFold(n_splits=k,shuffle=True)
K_results=cross_val_score(svr,x,y,cv=kfold)
accuracy=np.mean(abs(K_results))
accuracy
# Out:
# 0.20928537942344255

# %%
k=5
kfold=KFold(n_splits=k,shuffle=True)
K_results=cross_val_score(rfr,x,y,cv=kfold)
accuracy=np.mean(abs(K_results))
accuracy
# Out:
# 0.6889477148211227

# %%
k=5
kfold=KFold(n_splits=k,shuffle=True)
K_results=cross_val_score(model,x,y,cv=kfold)
accuracy=np.mean(abs(K_results))
accuracy
# Out:
# 0.6967945623839651

# %% [markdown]
# ### As the least difference between accuracy and cross validation score is for Linear Regression, it is our best model.

# %% [markdown]
# # Plot of Linear Regression

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Wins',fontsize=14)
plt.ylabel('Predicted Wins',fontsize=14)
plt.title('LinearRegression',fontsize=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Regularisation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1, random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.8448982975132351

# %%
cv_score=cross_val_score(ls,x,y,cv=2)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.6321238927701593

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters={'fit_intercept':[True,False],'normalize':[True,False],'n_jobs':[2,3,4,5,6,7,8,9,10]}
lr=LinearRegression()
clf=GridSearchCV(lr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'fit_intercept': True, 'n_jobs': 2, 'normalize': True}

# %%
lr=LinearRegression(fit_intercept= True,n_jobs= 2,normalize= True)
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
pred_decision=lr.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print('R2 score:',rfs*100)
# Out:
# R2 score: 86.76122846771182

# %% [markdown]
# # Model Saving

# %%
import pickle
filename='wins.pkl'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# # Prediction

# %%
loaded_model=pickle.load(open('wins.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.8676122846771182

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["Predicted","Original"])
conclusion
# Out:
#                    0          1          2          3          4          5  \
# Predicted  74.871082  91.145756  77.968702  66.607169  80.214822  80.580773
# Original   74.871082  91.145756  77.968702  66.607169  80.214822  80.580773
#
#                    6          7         8
# Predicted  70.634816  91.902981  81.83885
# Original   70.634816  91.902981  81.83885
