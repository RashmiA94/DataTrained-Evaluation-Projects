# %% [markdown]
# # Census Income Project

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Importing Libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the dataset

# %%
df=pd.read_csv('Census_Income_Project.csv')

# %% [markdown]
# First 5 Entries

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %% [markdown]
# Last 5 Entries

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# The dataset contains 32560 rows and 15 columns.

# %% [markdown]
# Data type of the features.

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# Columns of the dataset

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %% [markdown]
# Information about the features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # Class Imbalance

# %%
print(df['Income'].value_counts())
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
sns.countplot(x="Income",data=df);

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Statistical Calculation

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.describe(include="O")
# Out:
#        Workclass Education       Marital_status       Occupation Relationship  \
# count      32560     32560                32560            32560        32560
# unique         9        16                    7               15            6
# top      Private   HS-grad   Married-civ-spouse   Prof-specialty      Husband
# freq       22696     10501                14976             4140        13193
#
#           Race    Sex  Native_country  Income
# count    32560  32560           32560   32560
# unique       5      2              42       2
# top      White   Male   United-States   <=50K
# freq     27815  21789           29169   24719

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidths=0.1,linecolor='white');

# %% [markdown]
# Fnlwgt contain a outlier.

# %% [markdown]
# # Encoding the target variable

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Income"]=LE.fit_transform(df["Income"])

# %%
sns.countplot(x='Income',data=df);

# %% [markdown]
# # Checking Correlation

# %%
df.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
# Income          0.234039 -0.009481       0.335182      0.223333      0.150523
#
#                 Hours_per_week    Income
# Age                   0.068756  0.234039
# Fnlwgt               -0.018770 -0.009481
# Education_num         0.148127  0.335182
# Capital_gain          0.078409  0.223333
# Capital_loss          0.054256  0.150523
# Hours_per_week        1.000000  0.229690
# Income                0.229690  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='bar',color="r")
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Education_num is highly correlated with target variable and all other features are positively correlated with target variable.

# %%
sns.countplot(x="Workclass",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Private Workclass has the highest count.

# %%
sns.countplot(x="Education",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# HS-grad has the highest count.

# %%
sns.countplot(x="Marital_status",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Married-civ-spouse has the highest count.

# %%
sns.countplot(x="Occupation",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# In the occupation feature Prof-speciality and Craft-repair has the highest count.

# %%
sns.countplot(x="Relationship",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Among the relationships Husband count is highest.

# %%
sns.countplot(x="Race",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Among the race white race has the highest count.

# %%
sns.countplot(x="Sex",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Count of Male is highest.

# %%
plt.figure(figsize = (12,3))
sns.countplot(x="Native_country",data=df)
plt.xticks(rotation=90);
df.Native_country.value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %% [markdown]
# Majority people are native of United States.

# %%
sns.lineplot(x="Age",y="Income",data=df);

# %% [markdown]
# Income is highest for 50 Age.

# %%
plt.figure(figsize = (12,3))
sns.barplot(x="Workclass",y="Income",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Self-emp-inc has the highest income.

# %%
sns.stripplot(x="Fnlwgt",y="Race",data=df)
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Race'>

# %% [markdown]
# White and Black people have highest Fnlwgt.

# %%
plt.figure(figsize = (12,3))
sns.barplot(x="Education",y="Income",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Doctorate and Prof-school has the highest income.

# %%
plt.figure(figsize = (12,3))
sns.barplot(x="Marital_status",y="Income",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Married-AF-spouse has the highest income.

# %%
sns.barplot(x="Sex",y="Hours_per_week",hue="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Hours_per_week'>

# %% [markdown]
# Males has more hours_per_week of work and has more than 50K income.

# %%
sns.lineplot(x="Capital_gain",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Income'>

# %% [markdown]
# After 40000 Capital_gain income increases linearly.

# %%
plt.figure(figsize = (12,7))
sns.barplot(x="Native_country",y="Income",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Above plot shows that Iran and France has highest Income.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue="Income",size=3)

# %% [markdown]
# # Distribution Plot

# %%
numerical_features=df[df.select_dtypes(include=[np.number]).columns]

# %%
coll=numerical_features.columns.values
ncol=3
nrows=5

# %%
plt.figure(figsize=(30,30))
for i in range(0,len(coll)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(numerical_features[coll[i]])

# %% [markdown]
# Highly positively Skewed features are Capital_gain and Capital_loss.

# %% [markdown]
# # Box Plots showing outliers

# %%
collist=numerical_features.columns.values
ncol=2
nrows=4
plt.figure(figsize=(12,2*ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# # Encoding

# %%
LE=LabelEncoder()
df['Workclass']=LE.fit_transform(df['Workclass'])
df['Education']=LE.fit_transform(df['Education'])
df['Marital_status']=LE.fit_transform(df['Marital_status'])
df['Occupation']=LE.fit_transform(df['Occupation'])
df['Relationship']=LE.fit_transform(df['Relationship'])
df['Race']=LE.fit_transform(df['Race'])
df['Sex']=LE.fit_transform(df['Sex'])
df['Native_country']=LE.fit_transform(df['Native_country'])

# %%
df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# ...

# %% [markdown]
# # Separating x(Independent) and y(target) variable.

# %%
x=df.drop('Income',axis=1)
y=df['Income']

# %%
x.head(2)
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
#
#    Hours_per_week  Native_country
# 0              13              39
# 1              40              39

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Income, dtype: int32

# %% [markdown]
# # Balancing the Target Variable

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x_over,y_over=SM.fit_resample(x,y)
y_over.value_counts()
# Out:
# 1    24719
# 0    24719
# Name: Income, dtype: int64

# %%
sns.countplot(y_over)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# # Skewness

# %%
x_over.skew()
# Out:
# Age               0.348314
# Workclass        -0.755561
# Fnlwgt            1.428409
# Education        -0.969558
# Education_num    -0.427372
# Marital_status    0.319702
# Occupation        0.091250
# Relationship      1.120817
# Race             -2.476500
# Sex              -0.818878
# Capital_gain      8.363012
# Capital_loss      3.781703
# Hours_per_week    0.115887
# Native_country   -3.722854
# dtype: float64

# %%
for index in x_over.skew().index:
    if x_over.skew().loc[index]>0.5:
        x_over[index]=np.log1p(x_over[index])
    if x_over.skew().loc[index]<-0.5:
        x_over[index]=np.square(x_over[index])

# %%
x_over.skew()
# Out:
# Age               0.348314
# Workclass         1.151683
# Fnlwgt           -0.672563
# Education         0.246806
# Education_num    -0.427372
# Marital_status    0.319702
# Occupation        0.091250
# Relationship      0.655377
# Race             -2.133614
# Sex              -0.818878
# Capital_gain      2.289785
# Capital_loss      3.570675
# Hours_per_week    0.115887
# Native_country   -3.112928
# dtype: float64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_over=pd.DataFrame(scaler.fit_transform(x_over),columns=x_over.columns)
x_over.head()
# Out:
#         Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0  0.452055     0.5625  0.350563   0.360000       0.800000        0.333333
# 1  0.287671     0.2500  0.548798   0.537778       0.533333        0.000000
# 2  0.493151     0.2500  0.567240   0.004444       0.400000        0.333333
# 3  0.150685     0.2500  0.648299   0.360000       0.800000        0.333333
# 4  0.273973     0.2500  0.609623   0.640000       0.866667        0.333333
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0    0.285714      0.000000  1.00  1.0           0.0           0.0
# 1    0.428571      0.386853  1.00  1.0           0.0           0.0
# 2    0.428571      0.000000  0.25  1.0           0.0           0.0
# 3    0.714286      1.000000  0.25  0.0           0.0           0.0
# 4    0.285714      1.000000  1.00  0.0           0.0           0.0
#
#    Hours_per_week  Native_country
# 0        0.122449        0.904819
# 1        0.397959        0.904819
# ...

# %% [markdown]
# # Finding the best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x_over, y_over, test_size=0.3, random_state=i)
    lg = LogisticRegression()
    lg.fit(x_train, y_train)
    pred = lg.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
print("Best accuracy is: ",maxAccu,"on Random State: ",maxRS)
# Out:
# Best accuracy is:  0.7860706580366774 on Random State:  68

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_over, y_over, test_size=0.3, random_state=68)

# %% [markdown]
# # Model Selection

# %% [markdown]
# # Logistic Regression

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
lg.score(x_train,y_train)
pred=lg.predict(x_test)
print("accuracy_score:",)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy_score:
# 0.7860706580366774
# [[5689 1712]
#  [1461 5970]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78      7401
#            1       0.78      0.80      0.79      7431
#
#     accuracy                           0.79     14832
#    macro avg       0.79      0.79      0.79     14832
# weighted avg       0.79      0.79      0.79     14832

# %% [markdown]
# # KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print("accuracy_score:",)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# accuracy_score:
# 0.8574029126213593
# [[6262 1139]
#  [ 976 6455]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      7401
#            1       0.85      0.87      0.86      7431
#
#     accuracy                           0.86     14832
#    macro avg       0.86      0.86      0.86     14832
# weighted avg       0.86      0.86      0.86     14832

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(x_train,y_train)
gnb.score(x_train,y_train)
predgnb=gnb.predict(x_test)
print("accuracy_score:",)
print(accuracy_score(y_test,predgnb))
print(confusion_matrix(y_test,predgnb))
print(classification_report(y_test,predgnb))
# Out:
# accuracy_score:
# 0.7880933117583603
# [[5873 1528]
#  [1615 5816]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79      7401
#            1       0.79      0.78      0.79      7431
#
#     accuracy                           0.79     14832
#    macro avg       0.79      0.79      0.79     14832
# weighted avg       0.79      0.79      0.79     14832

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print("accuracy_score:",)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# accuracy_score:
# 0.8594255663430421
# [[6297 1104]
#  [ 981 6450]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      7401
#            1       0.85      0.87      0.86      7431
#
#     accuracy                           0.86     14832
#    macro avg       0.86      0.86      0.86     14832
# weighted avg       0.86      0.86      0.86     14832

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=100)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred=rf.predict(x_test)
print("accuracy_score:",)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy_score:
# 0.8984627831715211
# [[6652  749]
#  [ 757 6674]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      7401
#            1       0.90      0.90      0.90      7431
#
#     accuracy                           0.90     14832
#    macro avg       0.90      0.90      0.90     14832
# weighted avg       0.90      0.90      0.90     14832

# %% [markdown]
# # AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
ad=AdaBoostClassifier(n_estimators=100)
ad.fit(x_train,y_train)
ad.score(x_train,y_train)
pred=ad.predict(x_test)
print("accuracy_score:",)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy_score:
# 0.8702804746494067
# [[6312 1089]
#  [ 835 6596]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87      7401
#            1       0.86      0.89      0.87      7431
#
#     accuracy                           0.87     14832
#    macro avg       0.87      0.87      0.87     14832
# weighted avg       0.87      0.87      0.87     14832

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lg,x_over,y_over,cv=5)
print(score)
print(score.mean())
# Out:
# [0.75040453 0.77447411 0.78802589 0.78041873 0.78770102]
# 0.7762048567911248

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(knn,x_over,y_over,cv=5)
print(score)
print(score.mean())
# Out:
# [0.77811489 0.82281553 0.88076456 0.87974107 0.88196622]
# 0.8486804552445874

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(gnb,x_over,y_over,cv=5)
print(score)
print(score.mean())
# Out:
# [0.76152913 0.77942961 0.7818568  0.77920502 0.78497016]
# 0.7773981427018513

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(dtc,x_over,y_over,cv=5)
print(score)
print(score.mean())
# Out:
# [0.75889968 0.81573625 0.89178803 0.8958228  0.89177708]
# 0.8508047653697133

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(rf,x_over,y_over,cv=5)
print(score)
print(score.mean())
# Out:
# [0.78205906 0.85760518 0.92799353 0.93233539 0.93112167]
# 0.8862229663645799

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(ad,x_over,y_over,cv=5)
print(score)
print(score.mean())
# Out:
# [0.77578883 0.84223301 0.89087783 0.89177708 0.88823708]
# 0.8577827672766993

# %% [markdown]
# As the least difference between accuracy and cross validation score is for DecisionTreeClassifier it is our best model.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
parameter={'criterion':['gini','entropy'],'max_depth':list(np.arange(1,10)),'min_samples_split':list(np.arange(1,11)),
           'min_samples_leaf':list(np.arange(1,10))}
GCV=GridSearchCV(DecisionTreeClassifier(),parameter,cv=5)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 9,
#  'min_samples_leaf': 3,
#  'min_samples_split': 10}

# %%
Final_mod=DecisionTreeClassifier(criterion='gini',max_depth=9,min_samples_split=10,min_samples_leaf=3)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 87.10221143473571

# %% [markdown]
# # AUC-ROC CURVE

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
y_pred_prob=dtc.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='DecisionTreeClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('DecisionTreeClassifier')
plt.show()
auc_score=roc_auc_score(y_test,dtc.predict(x_test))
auc_score
# Out:
# 0.8594082175389341

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(dtc,'dtcfile.obj')
# Out:
# ['dtcfile.obj']

# %% [markdown]
# # Prediction

# %%
dtc_from_joblib=joblib.load('dtcfile.obj')
dtc_from_joblib.predict(x_test)
# Out:
# array([0, 1, 1, ..., 1, 0, 1])
